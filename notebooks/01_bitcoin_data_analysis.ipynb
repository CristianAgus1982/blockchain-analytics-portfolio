# %%
# Bitcoin Data Analysis - First Project
# Author: Cristian Garcia
# Date: January 19, 2026

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("✅ Libraries loaded successfully")
# Out:
# ✅ Libraries loaded successfully

# %%
# !pip install mplfinance

# %%
from datetime import datetime, timedelta
import mplfinance as mpf

# Download Bitcoin data from 2016 to yesterday
yesterday = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')
print(f"📥 Downloading Bitcoin data from 2016-01-01 to {yesterday}...")

btc_data = yf.download('BTC-USD', start='2016-01-01', end=yesterday)
print(f"✅ Downloaded {len(btc_data)} days of Bitcoin data")
# Out:
# 📥 Downloading Bitcoin data from 2016-01-01 to 2026-01-18...
# C:\Users\paran\AppData\Local\Temp\ipykernel_15392\512171344.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   btc_data = yf.download('BTC-USD', start='2016-01-01', end=yesterday)
# [*********************100%***********************]  1 of 1 completed
# ✅ Downloaded 3670 days of Bitcoin data

# %%
# Fix data format first
btc_data.columns = btc_data.columns.droplevel(1)  # Remove multi-level columns

# Create candlestick chart
mpf.plot(btc_data, 
         type='candle',
         style='charles',
         title='📊 Bitcoin Price - Candlestick Chart (2016-2026)',
         ylabel='Price (USD)',
         volume=True,
         figsize=(16, 8))

print(f"💰 Highest price: ${btc_data['Close'].max():,.2f}")
print(f"📉 Lowest price: ${btc_data['Close'].min():,.2f}")
print(f"📅 Date range: {btc_data.index[0].strftime('%Y-%m-%d')} to {btc_data.index[-1].strftime('%Y-%m-%d')}")
# Out:
# c:\Users\paran\anaconda3\envs\Test\Lib\site-packages\mplfinance\_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+
# c:\Users\paran\anaconda3\envs\Test\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 💰 Highest price: $124,752.53
# 📉 Lowest price: $364.33
# 📅 Date range: 2016-01-01 to 2026-01-17
